# %%
import cv2

# %%
print("opencv version:", cv2.__version__)
# Out:
# opencv version: 4.8.0

# %%
# !pip install matplotlib==3.4.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 38.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for matplotlib: filename=matplotlib-3.4.2-cp310-cp310-linux_x86_64.whl size=10437180 sha256=bea432e44cac297f74a506d145c5803027d74ac19af3fcecab3b4cc2ac81ceb3
#   Stored in directory: /root/.cache/pip/wheels/d9/e8/73/f806fc40c211022378c2828e3cce1eac412344111ab1becd9d
# Successfully built matplotlib
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.6.0 requires matplotlib>=3.7.1, but you have matplotlib 3.4.2 which is incompatible.
# mizani 0.9.3 requires matplotlib>=3.5.0, but you have matplotlib 3.4.2 which is incompatible.
# ...

# %%
# !pip install numpy==1.19.5
# !pip install tqdm==4.62.0
# !pip install scipy==1.6.2
# !pip install tensorflow==2.6.0
# !pip install scikit-learn==0.24.2
# Out:
# ...
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ERROR: Operation cancelled by user
# ...
# ERROR: Ignored the following versions that require a different python version: 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10
# ...

# %%
import cv2
import matplotlib
import numpy as np
import tqdm
import scipy
import tensorflow as tf
import sklearn

print("opencv version:", cv2.__version__)
print("matplotlib version:", matplotlib.__version__)
print("numpy version:", np.__version__)
print("tqdm version:", tqdm.__version__)
print("scipy version:", scipy.__version__)
print("tensorflow version:", tf.__version__)
print("scikit-learn version:", sklearn.__version__)
# Out:
# opencv version: 4.8.0
# matplotlib version: 3.7.1
# numpy version: 1.25.2
# tqdm version: 4.66.4
# scipy version: 1.11.4
# tensorflow version: 2.15.0
# scikit-learn version: 1.2.2

# %%
# !python ./PRANet-Polyps-Segmentation/train_pranet.py --data_path ./polyps_dataset \
                        --data_split 0.1 \
                        --epoch 25 \
                        --lr 1e-4 \
                        --batchsize 16 \
                        --inputsize 352 \
                        --gclip 0.5 \
                        --trained_model_path /content/drive/MyDrive/PraNettt/Trained_model \
                        --backbone resnet50
# Out:
# ...
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "PRAnet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 352, 352, 3)]        0         []
#
#  resnet50_include_top_false  [(None, 88, 88, 256),        2358771   ['input_2[0][0]']
#   (Functional)                (None, 44, 44, 512),        2
#                               (None, 22, 22, 1024),
#                               (None, 11, 11, 2048)]
#
#  rfb_4 (RFB)                 (None, 11, 11, 32)           392544    ['resnet50_include_top_false[0
#                                                                     ][3]']
#
#  rfb_3 (RFB)                 (None, 22, 22, 32)           228704    ['resnet50_include_top_false[0
#                                                                     ][2]']
#
# ...

# %%
# !python ./PRANet-Polyps-Segmentation/test_pranet.py --data_path ./polyps_dataset/ \
                       --model_path /content/drive/MyDrive/PraNettt/Trained_modelpranet_resnet50/ \
                       --inputsize 352
# Out:
# 2024-06-23 09:12:37.453793: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-23 09:12:37.453846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-23 09:12:37.455232: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-23 09:12:38.554776: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-23 09:12:40.228221: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...

# %%
# !python ./PRANet-Polyps-Segmentation/polyps_seg_image.py --model_path ./Trained_modelpranet_resnet50 \
                            --image_path /content/PRANet-Polyps-Segmentation/sample_polyps/polyps1.jpg \
                            --inputsize 352
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_539460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# [info] loaded model
# [info] Computing output mask..
# Total runtime of model: 4147.75ms
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# !python ./PRANet-Polyps-Segmentation/polyps_seg_video.py --model_path ./Trained_modelpranet_resnet50 \
                            --video_path ./PRANet-Polyps-Segmentation/sample_polyps/Colonoscopy.mp4 \
                            --inputsize 352 \
                            --threshold 0.5
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_539460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# [info] loaded model
# Frames per second :  30.0 FPS
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Inference time for one frame: 4609.802007675171ms
# Inference time for one frame: 33.99252891540527ms
# Inference time for one frame: 34.46364402770996ms
# Inference time for one frame: 34.8360538482666ms
# Inference time for one frame: 45.9895133972168ms
# Inference time for one frame: 42.89507865905762ms
# Inference time for one frame: 32.99522399902344ms
# Inference time for one frame: 32.43374824523926ms
# Inference time for one frame: 32.546043395996094ms
# Inference time for one frame: 44.779062271118164ms
# Inference time for one frame: 31.438827514648438ms
# ...
